# %%
# Importing the basic Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
from pathlib import Path
from plotly.offline import iplot, init_notebook_mode, plot

# %%
# Initialize Plotly for offline mode
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.30.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# Ensure plots are displayed inline in Jupyter Notebook
# %matplotlib inline

# %%
# Increase the display max columns to show all columns in pandas DataFrames
pd.set_option('display.max_columns', None)

# %%
# Load the dataset
hr = pd.read_csv('HR-Employee-Attrition.csv')

# %%
hr.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %%
hr.shape
# Out:
# (1470, 35)

# %%
hr.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
hr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
print("No. of Null values in our dataset:-")
print(hr.isnull().sum())
print('_'*40)
print('No. of Dulicated values in our dataset:-',hr.duplicated().sum())
print()
# Out:
# No. of Null values in our dataset:-
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# ...

# %%
def print_column_info(dataframe, columns):
    for col in columns:
        print('_'*40)
        print('Unique values:')
        print(dataframe[col].unique())
        print('-'*40)
        print('Value counts:')
        print(dataframe[col].value_counts())
        print('_'*40)

# Extract object type columns
obj_cols = list(hr.select_dtypes(include='object').columns)

# Print information for object type columns
print_column_info(hr, obj_cols)
# Out:
# ________________________________________
# Unique values:
# ['Yes' 'No']
# ----------------------------------------
# Value counts:
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64
# ________________________________________
# ________________________________________
# Unique values:
# ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
# ----------------------------------------
# Value counts:
# BusinessTravel
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: count, dtype: int64
# ________________________________________
# ________________________________________
# Unique values:
# ['Sales' 'Research & Development' 'Human Resources']
# ----------------------------------------
# Value counts:
# Department
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: count, dtype: int64
# ________________________________________
# ________________________________________
# ...

# %%
import math  # Make sure math is imported

def detect_and_plot_outliers(dataframe, numerical_columns):
    # Set up the subplots
    num_cols = len(numerical_columns)
    num_rows = math.ceil(num_cols / 3)
    
    plt.figure(figsize=(15, 5 * num_rows))
    
    for i, col in enumerate(numerical_columns, 1):
        plt.subplot(num_rows, 3, i)
        
        # Box plot
        sns.boxplot(x=dataframe[col], color='skyblue', width=0.8, linewidth=1.5, fliersize=5)
        plt.title(f'Box Plot of {col}')
        plt.xlabel(col)
        
        # Detect and mark outliers using the IQR method
        Q1 = dataframe[col].quantile(0.25)
        Q3 = dataframe[col].quantile(0.75)
        IQR = Q3 - Q1
        
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        
        outliers = (dataframe[col] < lower_bound) | (dataframe[col] > upper_bound)
        plt.scatter(dataframe[col][outliers], dataframe[col][outliers], color='red', marker='x', s=50, label='Outliers')
    
    plt.tight_layout()
    plt.show()

# Extract numerical columns
num_cols = hr.select_dtypes(include=['int64', 'float64']).columns

# Detect and plot outliers for numerical columns
detect_and_plot_outliers(hr, num_cols)

# %%
def plot_distribution_by_attrition(dataframe, categorical_columns):
    # Define custom color palette
    custom_palette = ['#1F7784', '#AEC7E8']
    
    # Plotting the distribution of each object column grouped by Attrition
    for column in categorical_columns:
        plt.figure(figsize=(18, 6))
        sns.countplot(data=dataframe, x=column, hue='Attrition', palette=custom_palette, edgecolor=".6", linewidth=1.5)
        plt.title(f"Distribution of {column} by Attrition")
        plt.xlabel(column)
        plt.ylabel("Frequency")
        plt.xticks(rotation=45)
        plt.legend(title='Attrition', loc='upper right')
        
        # Add annotations
        for p in plt.gca().patches:
            plt.gca().annotate(f"{p.get_height()}", (p.get_x() + p.get_width() / 2., p.get_height()),
                               ha='center', va='center', xytext=(0, 10), textcoords='offset points')
        
        plt.tight_layout()
        plt.show()

# Extract object type columns excluding 'Attrition'
obj_columns = hr.select_dtypes(include='object').drop(['Attrition'], axis=1)

# Plot distribution by Attrition for object type columns
plot_distribution_by_attrition(hr, obj_columns)

# %%
def generate_advanced_pie_charts(dataframe, categorical_columns):
    for column in categorical_columns:
        plt.figure(figsize=(15, 6))
        
        # Count the occurrences of each unique value in the column
        category_counts = dataframe[column].value_counts()
        
        # Define a custom color palette
        custom_palette = sns.color_palette("Paired", len(category_counts))
        
        # Generate a pie chart using the custom color palette
        plt.pie(category_counts, labels=category_counts.index, autopct='%1.1f%%', startangle=90, colors=custom_palette)
        
        plt.title(f'Pie Chart of the column "{column}"')
        plt.axis('equal')  # Equal aspect ratio ensures that the pie is drawn as a circle.
        
        plt.show()

# Generate advanced pie charts for object type columns
generate_advanced_pie_charts(hr, obj_cols)

# %%
edu_emp_df = hr.EducationField.value_counts()
edu_emp_df
# Out:
# EducationField
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6))
plt.pie(edu_emp_df,labels=edu_emp_df.index,autopct='%1.1f%%')
plt.title('Employees Education Field')
plt.show()

# %%
#Finding the number of employees in each deparment and also classifying them into business travel.
dept_travel_df=hr.groupby(['Department','BusinessTravel'], as_index=False).count()
dept_travel_df
# Out:
#                Department     BusinessTravel  Age  Attrition  DailyRate  \
# 0         Human Resources         Non-Travel    6          6          6
# 1         Human Resources  Travel_Frequently   11         11         11
# 2         Human Resources      Travel_Rarely   46         46         46
# 3  Research & Development         Non-Travel   97         97         97
# 4  Research & Development  Travel_Frequently  182        182        182
# 5  Research & Development      Travel_Rarely  682        682        682
# 6                   Sales         Non-Travel   47         47         47
# 7                   Sales  Travel_Frequently   84         84         84
# 8                   Sales      Travel_Rarely  315        315        315
#
#    DistanceFromHome  Education  EducationField  EmployeeCount  EmployeeNumber  \
# 0                 6          6               6              6               6
# 1                11         11              11             11              11
# ...

# %%
plt.figure(figsize=(12, 8))
sns.barplot(x='Department', y='EmployeeCount', hue='BusinessTravel', data=dept_travel_df, palette="viridis")
plt.xlabel('Departments', fontsize=14)
plt.ylabel('Number of Employees', fontsize=14)
plt.title('Employees in Various Departments with Business Travel', fontsize=16)
plt.legend(title='Business Travel', title_fontsize='14', loc='upper right')
for p in plt.gca().patches:
    plt.gca().annotate(f'{int(p.get_height())}', (p.get_x() + p.get_width() / 2., p.get_height()), 
                       ha='center', va='center', xytext=(0, 10), textcoords='offset points', fontsize=10)

plt.xticks(rotation=45, ha='right', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# Define a custom palette with grey, blue, and light blue
custom_palette = ['#808080', '#0000FF', '#ADD8E6']

plt.figure(figsize=(12, 8))
sns.barplot(x='Department', y='EmployeeCount', hue='BusinessTravel', data=dept_travel_df, palette=custom_palette)
plt.xlabel('Departments', fontsize=14)
plt.ylabel('Number of Employees', fontsize=14)
plt.title('Employees in Various Departments with Business Travel', fontsize=16)
plt.legend(title='Business Travel', title_fontsize='14', loc='upper right')

# Annotate each bar with the height
for p in plt.gca().patches:
    plt.gca().annotate(f'{int(p.get_height())}', 
                       (p.get_x() + p.get_width() / 2., p.get_height()), 
                       ha='center', va='center', 
                       xytext=(0, 10), textcoords='offset points', fontsize=10)

plt.xticks(rotation=45, ha='right', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# Selecting only the numeric columns
numeric_columns = hr.select_dtypes(include='number')

# Calculate the correlation matrix
corr_matrix = numeric_columns.corr()

# Creating the heatmap using Seaborn and Matplotlib
plt.figure(figsize=(12, 10))
sns.heatmap(corr_matrix, annot=True, fmt='.2f', cmap='coolwarm', cbar=True, square=True, linewidths=.5, annot_kws={'size': 10})
plt.title("Correlation Heatmap", fontsize=16)
plt.show()

# %%
# Split the dataframe based on the Attrition column
attr_yes_df = hr[hr['Attrition'] == 'Yes']
attr_no_df = hr[hr['Attrition'] == 'No']

# Calculate value counts for EducationField and JobRole
dept_count_yes = attr_yes_df['EducationField'].value_counts()
dept_count_no = attr_no_df['EducationField'].value_counts()
job_role_yes = attr_yes_df['JobRole'].value_counts()
job_role_no = attr_no_df['JobRole'].value_counts()

# Create subplots
fig, axes = plt.subplots(1, 2, figsize=(20, 6))

# Pie chart for EducationField distribution
axes[0].pie(dept_count_yes * 100 / dept_count_no, wedgeprops=dict(width=0.6), labels=(dept_count_yes / dept_count_no).index, autopct='%1.1f%%', startangle=180)
axes[0].text(0., 0., '', horizontalalignment='center', verticalalignment='center')
axes[0].axis('equal')
axes[0].set_title('Education Field Distribution by Attrition')

# Pie chart for JobRole distribution
axes[1].pie(job_role_yes * 100 / job_role_no, wedgeprops=dict(width=0.6), labels=(job_role_yes / job_role_no).index, autopct='%1.1f%%', startangle=180)
axes[1].text(0., 0., '', horizontalalignment='center', verticalalignment='center')
axes[1].axis('equal')
axes[1].set_title('Job Role Distribution by Attrition')

plt.show()

# %%
# Plotting the line plot
plt.figure(figsize=(10, 6))
sns.lineplot(data=hr, y='JobLevel', x='YearsInCurrentRole')
plt.title('Career Growth')
plt.xlabel('Years In Current Role')
plt.ylabel('Job Level')
plt.show()
